# %%
import pandas as pd
data = pd.read_csv(r'\\file\Usersn$\npa95\Home\Desktop\data\d_violence\ARG.csv')
data.head(3)
# Out:
#               Table 3             Anzsoc Division  \
# 0  3 Age ROV Boundary  Theft and Related Offences
# 1  3 Age ROV Boundary  Theft and Related Offences
# 2  3 Age ROV Boundary  Theft and Related Offences
#
#                             Anzsoc Group  \
# 0  Theft (Except Motor Vehicles), N.E.C.
# 1  Theft (Except Motor Vehicles), N.E.C.
# 2  Theft (Except Motor Vehicles), N.E.C.
#
#                                 Anzsoc Subgroup Age Group  \
# 0  Theft (Except Motor Vehicles & Boat), N.E.C.       20+
# 1  Theft (Except Motor Vehicles & Boat), N.E.C.       20+
# 2  Theft (Except Motor Vehicles & Boat), N.E.C.       20+
#
#               Anzsoc Subdivision Location Type Location Type Description  \
# 0  Theft (Except Motor Vehicles)    Open Space                Open Space
# 1  Theft (Except Motor Vehicles)  Public Place              Public Place
# 2  Theft (Except Motor Vehicles)  Public Place              Public Place
#
#   Location Type Division Person/Organisation  ...            Rov Division  \
# 0     Community Location              Person  ...  No Offender Identified
# 1     Community Location              Person  ...  No Offender Identified
# 2     Community Location              Person  ...  No Offender Identified
#
#                     Rov Group          Rov Subdivision Territorial Authority  \
# 0  No Further Line Of Enquiry  Investigation Suspended   Far North District.
# 1  No Further Line Of Enquiry  Investigation Suspended   Far North District.
# 2  No Further Line Of Enquiry  Investigation Suspended   Far North District.
#
#            Weapon Weapons filter    Weapons Used Year Month Number of Records  \
# 0  Not Applicable          False  Not Applicable  11/1/2014                 1
# 1  Not Applicable          False  Not Applicable  11/1/2014                 1
# 2  Not Applicable          False  Not Applicable  11/1/2014                 1
#
#    Victimisations
# 0               1
# 1               1
# 2               1
#
# [3 rows x 24 columns]

# %%
# See what columns are there
data.columns
# Out:
# Index(['Table 3', 'Anzsoc Division', 'Anzsoc Group', 'Anzsoc Subgroup',
#        'Age Group', 'Anzsoc Subdivision', 'Location Type',
#        'Location Type Description', 'Location Type Division',
#        'Person/Organisation', 'Police Area', 'Police District',
#        'Police Station', 'ROV  Division', 'Rov Division', 'Rov Group',
#        'Rov Subdivision', 'Territorial Authority', 'Weapon', 'Weapons filter',
#        'Weapons Used', 'Year Month', 'Number of Records', 'Victimisations'],
#       dtype='object')

# %%
# Choose the columns that are helpful
print(data.columns)
cols = ['Anzsoc Division','Age Group', 'Location Type',
             'Location Type Division','Police Area', 'Police District',
       'Police Station', 'ROV  Division', 'Rov Group', 'Rov Subdivision', 'Year Month',
             'Victimisations']
data = data[cols]
# Out:
# Index(['Table 3', 'Anzsoc Division', 'Anzsoc Group', 'Anzsoc Subgroup',
#        'Age Group', 'Anzsoc Subdivision', 'Location Type',
#        'Location Type Description', 'Location Type Division',
#        'Person/Organisation', 'Police Area', 'Police District',
#        'Police Station', 'ROV  Division', 'Rov Division', 'Rov Group',
#        'Rov Subdivision', 'Territorial Authority', 'Weapon', 'Weapons filter',
#        'Weapons Used', 'Year Month', 'Number of Records', 'Victimisations'],
#       dtype='object')

# %%
# See the chosen columns 
print(data.shape)
data.head(2)
# Out:
# (732404, 12)
#               Anzsoc Division Age Group Location Type Location Type Division  \
# 0  Theft and Related Offences       20+    Open Space     Community Location
# 1  Theft and Related Offences       20+  Public Place     Community Location
#
#       Police Area Police District Police Station           ROV  Division  \
# 0  Far North Area       Northland         Paihia  No Offender Identified
# 1  Far North Area       Northland        Kaikohe  No Offender Identified
#
#                     Rov Group          Rov Subdivision Year Month  \
# 0  No Further Line Of Enquiry  Investigation Suspended  11/1/2014
# 1  No Further Line Of Enquiry  Investigation Suspended  11/1/2014
#
#    Victimisations
# 0               1
# 1               1

# %%
# Check unique value of the columns
for i in range(len(cols)):
    unique = data[cols[i]].unique()
    print(cols[i], 'values are: \n', unique)
    print('='*30)
# Out:
# Anzsoc Division values are:
#  ['Theft and Related Offences'
#  'Unlawful Entry With Intent/Burglary, Break and Enter'
#  'Abduction, Harassment and Other Related Offences Against a Person'
#  'Acts Intended to Cause Injury' 'Sexual Assault and Related Offences'
#  'Robbery, Extortion and Related Offences']
# ==============================
# Age Group values are:
#  ['20+' 'Not Applicable' '0-9' 'Not Specified' '10-19']
# ==============================
# Location Type values are:
#  ['Open Space' 'Public Place' 'Health' 'Educational'
#  'Community Location N.F.D.' 'Other Location N.F.D.' 'Recreational'
#  'Retail N.E.C.' 'Service Station' 'Administrative/Professional'
#  'Agricultural Land' 'Agricultural Outbuilding' 'Not Applicable'
#  'Dwelling N.F.D.' 'Chemistry/Pharmacy' 'Dwelling Outbuilding'
#  'Dwelling Land' 'Justice' 'Unspecified Location' 'Dwelling - Private'
#  'Dwelling - Non-Private' 'Suppressed' 'Other Location N.E.C.'
#  'Outbuilding/Residential Land' 'Car Park' 'Banking' 'Religious'
#  'Street/Footpath' 'Agricultural' 'Terminal' 'Manufacturing'
#  'Conveyance In Transit' 'Retail N.F.D.' 'Residential Location N.F.D.'
#  'Warehousing/Storage' 'Community Location N.E.C.']
# ==============================
# Location Type Division values are:
#  ['Community Location' 'Other Location' 'Not Applicable'
#  'Residential Location' 'Unspecified Location' 'Suppressed']
# ==============================
# Police Area values are:
#  ['Far North Area' 'Whangarei Area' 'Otago Coastal Area'
#  'Otago Lakes Central Area' 'Southland Area' 'Marlborough Area'
#  'Nelson Bays Area' 'West Coast Area' 'Hamilton City Area'
#  'Waikato West Area' 'Waikato East Area' 'Canterbury Rural Area'
#  'Mid / South Canterbury Area' 'Canterbury Metro Area' 'Whanganui Area'
#  'Manawatu Area' 'Taranaki Area' 'Counties Manukau East Area'
#  'Hutt Valley Area' 'Counties Manukau West Area' 'Hawkes Bay Area'
#  'Auckland Central Area' 'Taupo Area' 'Wellington Area'
#  'Counties Manukau South Area' 'Waitemata West Area' 'Rotorua Area'
#  'Waitemata East Area' 'Eastern Bay Of Plenty Area' 'Auckland East Area'
#  'Auckland West Area' 'Western Bay Of Plenty Area'
#  'Counties Manukau Central Area' 'Tairawhiti Area' 'Waitemata North Area'
#  'Kapiti-Mana Area' 'Wairarapa Area' 'Auckland Motorways Area'
#  'Not Specified']
# ==============================
# Police District values are:
#  ['Northland' 'Southern' 'Tasman' 'Waikato' 'Canterbury' 'Central'
#  'Counties/Manukau' 'Wellington' 'Eastern' 'Auckland City' 'Bay Of Plenty'
#  'Waitemata' 'Not Specified']
# ==============================
# Police Station values are:
#  ['Paihia' 'Kaikohe' 'Kaitaia' 'Kawakawa' 'Kerikeri' 'Dargaville'
#  'Onerahi CPC' 'Whangarei' 'Dunedin North' 'Kaikorai Valley'
#  'Dunedin Central' 'Dunedin South' 'Mosgiel' 'Queenstown' 'Wanaka'
#  'Mataura' 'Invercargill Central' 'Riverton' 'Te Anau' 'Winton' 'Picton'
#  'Takaka' 'Richmond' 'Blenheim' 'Havelock' 'Nelson Central' 'Motueka'
#  'Wakefield' 'Granity' 'Reefton' 'Westport' 'Greymouth' 'Hamilton Central'
#  'Hamilton East' 'Raglan' 'Cambridge' 'Te Awamutu' 'Paeroa' 'Matamata'
#  'Morrinsville' 'Tairua' 'Huntly' 'Rangiora' 'Temuka' 'Timaru' 'Papanui'
#  'Christchurch' 'Hornby' 'Ashburton' 'Whanganui' 'Dannevirke' 'Hawera'
#  'Otaki' 'Feilding' 'Foxton' 'Linton' 'Palmerston North' 'Waitara'
#  'Eltham' 'Opunake' 'Stratford' 'Levin' 'Highbury' 'Woodville'
#  'Fitzroy CPC' 'Inglewood' 'Marton' 'Raetihi' 'Taumarunui'
#  'New Plymouth Central' 'Taihape' 'Ormiston' 'Lower Hutt' 'Otahuhu'
#  'Hastings' 'Lincoln' 'Auckland Central' 'Tokoroa' 'Wellington Central'
#  'Papakura' 'Kilbirnie' 'Napier' 'Henderson' 'Mangere' 'Rotorua'
#  'New Lynn' 'Takapuna' 'Whakatane' 'Glen Innes' 'Mount Wellington'
#  'Avondale' 'Balmoral' 'Taupo' 'Tauranga' 'Te Puke' 'New Brighton'
#  'Pukekohe' 'Howick' 'Manurewa' 'Flaxmere' 'Gisborne' 'Kamo CPC' 'Ruawai'
#  'Balclutha' 'Glenfield' 'Whangaparaoa' 'Kapiti' 'Waihi' 'Tauranga South'
#  'Katikati' 'Christchurch South' 'Rakaia' 'Shannon' 'Tuakau' 'Bay View'
#  'Te Karaka' 'Havelock North' 'Wairoa' 'Waipukurau' 'Porangahau'
#  'Mangonui' 'Hikurangi' 'Kaeo' 'Waipu' 'Ruakaka' 'Milton' 'Lumsden'
#  'Otautau' 'Riversdale' 'Hampden' 'Oamaru' 'Tapanui' 'Wyndham' 'Gore'
#  'Alexandra' 'Hokitika' 'Ngaruawahia' 'Te Aroha' 'Wellsford'
#  'Kumeu/Huapai' 'Orewa' 'Massey' 'Browns Bay'
#  'North Shore Policing Centre' 'Helensville' 'Warkworth' 'Waitangirua'
#  'Carterton' 'Featherston' 'Rolleston' 'Westown' 'Beachlands CCB'
#  'Russell' 'Green Island' 'Thames' 'Wainuiomata' 'Porirua Central'
#  'Upper Hutt' 'Waiheke Island' 'Newmarket' 'Onehunga' 'Ponsonby' 'Akaroa'
#  'Amberley' 'Cheviot' 'Hanmer Springs' 'Darfield' 'Methven' 'Manaia'
#  'Maungaturoto' 'Kurow' 'Naenae' 'Masterton' 'Martinborough'
#  'Johnsonville' 'Houhora' 'Clinton' 'Port Chalmers' 'Auckland Airport'
#  'Bulls' 'Patea' 'Nuhaka' 'Leeston' 'Waipawa' 'Otorohanga' 'Te Kuiti'
#  'Opotiki' 'Geraldine' 'Culverden' 'Cromwell' 'Whitianga'
#  'Mount Maunganui' 'Edgecumbe' 'Turangi' 'Taradale' 'Ranfurly'
#  'Coromandel' 'Ngatea' 'Papamoa' 'Kaiapoi' 'Twizel' 'Taneatua' 'Pahiatua'
#  'Okato' 'Putaruru' 'Kawerau' 'Rawene' 'Portobello' 'Murupara' 'Waimate'
#  'Kaikoura' 'Whangamata' 'Kawhia' 'Lyttelton' 'Kohukohu' 'Bell Block'
#  'Roxburgh' 'Te Kauwhata' 'Mangawhai' 'Te Kaha' 'Mangakino' 'Waikari'
#  'Oxford' 'Pleasant Point' 'St Andrews' 'Arthurs Pass' 'Karamea'
#  'Murchison' 'Waverley' 'Eketahuna' 'Tolaga Bay' 'Greytown' 'Ohai'
#  'Kimbolton' 'Ohakune' 'Fairlie' 'Auckland Harbour Bridge' 'Waikouaiti'
#  'Bluff' 'Christchurch Airport' 'Te Araroa' 'Middlemarch' 'Ross'
#  'Great Barrier Island' 'National Park' 'Waiouru' 'Tokomaru Bay'
#  'Lake Tekapo' 'Piopio' 'Omarama' 'Half-Moon Bay' 'Haast' 'Manutuke'
#  'Ruatoria' 'Pongaroa' 'Mokau' 'Matawai' 'Owaka' 'Tuatapere' 'Lawrence'
#  'Palmerston' 'Omakau' 'Chatham Islands' 'Norsewood' 'Kotemaori'
#  'Benneydale' 'Franz Josef' 'Hunterville' 'Tuai' 'Not Known']
# ==============================
# ROV  Division values are:
#  ['No Offender Identified' 'Not Applicable' 'Known To Victim' 'Not Stated'
#  'Stranger']
# ==============================
# Rov Group values are:
#  ['No Further Line Of Enquiry' 'Not Applicable' 'Other Family'
#  'Other Non Family' 'No Offender Identified N.F.D.'
#  'Not Stated / Inadequately Described' 'Stranger'
#  'Investigation Continuing' 'Partner' 'Ex-Partner/Boy/Girlfriend']
# ==============================
# Rov Subdivision values are:
#  ['Investigation Suspended' 'Not Applicable' 'Family Member'
#  'Non Family Member' 'No Offender Identified N.F.D.'
#  'Not Stated / Inadequately Described' 'Stranger'
#  'Investigation Continuing' '.']
# ==============================
# Year Month values are:
#  ['11/1/2014' '8/1/2014' '7/1/2014' '9/1/2014' '10/1/2014' '1/1/2015'
#  '2/1/2015' '12/1/2014' '4/1/2015' '3/1/2015' '5/1/2015' '6/1/2015'
#  '7/1/2015' '8/1/2015' '9/1/2015' '10/1/2015' '12/1/2015' '11/1/2015'
#  '1/1/2016' '3/1/2016' '2/1/2016' '4/1/2016' '5/1/2016' '7/1/2016'
#  '8/1/2016' '6/1/2016' '9/1/2016' '11/1/2016' '12/1/2016' '10/1/2016'
#  '1/1/2017' '2/1/2017' '3/1/2017' '4/1/2017' '7/1/2017' '9/1/2017'
#  '8/1/2017' '6/1/2017' '5/1/2017' '10/1/2017' '12/1/2017' '11/1/2017'
#  '2/1/2018' '1/1/2018' '5/1/2018' '6/1/2018' '3/1/2018' '4/1/2018'
#  '7/1/2018' '8/1/2018' '10/1/2018' '9/1/2018' '11/1/2018' '12/1/2018'
#  '1/1/2019' '2/1/2019' '4/1/2019' '5/1/2019' '3/1/2019' '7/1/2019'
#  '10/1/2019' '11/1/2019' '6/1/2019' '8/1/2019' '9/1/2019' '12/1/2019'
#  '1/1/2020' '2/1/2020' '3/1/2020' '6/1/2020' '5/1/2020' '4/1/2020']
# ==============================
# Victimisations values are:
#  [  1   3   8   4   2   6  22   9  13  12  18  11   7   5  16  10  15  19
#   25  27  17  33  14  24  53  41  51  57  87  59  30  77  20  21  49  43
#   36 101  40  31  26  23  46  29  37  32  98  85  45  47 155  65  35  81
#   39  73  93  34  28  60  61 121  55 113  74 152  50  42  89  48 115  75
#   38  68  96 160  90  63  78  70 127  66  86  54  62 131  52 140 100  58
#   83  56 106  82  88 103 116 120  67  64 147 144 102  44  95  79  94 110
#   97 117  69  71  99  72  84 169 122 173 104  76 151 111  80 129  91 128
#  133 107 119 154  92 132 114 124 112 109 105 142 134 123 108 118 145 135]
# ==============================

# %%
#Choose rows only containing 'Family Member' 'Non Family Member' 
# And only leave data for "Western Bay of Plenty Area"

df =  data[(data['Rov Subdivision'].str.contains('Family')) & (data['Police Area']== 'Western Bay Of Plenty Area')]
df.shape
# 4184 cases can be identified as ROV 'Family Member' or 'Non Family Member' in western bay of plenty area
# Out:
# (4184, 12)

# %%
df.head()
# Out:
#                          Anzsoc Division Age Group    Location Type  \
# 158        Acts Intended to Cause Injury       0-9  Dwelling N.F.D.
# 160        Acts Intended to Cause Injury       0-9  Dwelling N.F.D.
# 801  Sexual Assault and Related Offences       0-9     Public Place
# 841        Acts Intended to Cause Injury     10-19     Public Place
# 843        Acts Intended to Cause Injury     10-19     Public Place
#
#     Location Type Division                 Police Area Police District  \
# 158   Residential Location  Western Bay Of Plenty Area   Bay Of Plenty
# 160   Residential Location  Western Bay Of Plenty Area   Bay Of Plenty
# 801     Community Location  Western Bay Of Plenty Area   Bay Of Plenty
# 841     Community Location  Western Bay Of Plenty Area   Bay Of Plenty
# 843     Community Location  Western Bay Of Plenty Area   Bay Of Plenty
#
#     Police Station    ROV  Division     Rov Group Rov Subdivision Year Month  \
# 158       Tauranga  Known To Victim  Other Family   Family Member   7/1/2014
# 160        Te Puke  Known To Victim  Other Family   Family Member   7/1/2014
# 801       Tauranga  Known To Victim  Other Family   Family Member   7/1/2014
# 841       Tauranga  Known To Victim  Other Family   Family Member   7/1/2014
# 843        Te Puke  Known To Victim  Other Family   Family Member   7/1/2014
#
#      Victimisations
# 158               1
# 160               1
# 801               1
# 841               1
# 843               1

# %%
# Save the cleaned data table to a csv file then use Tableau for visualisation 
df.to_csv(r'\\file\Usersn$\npa95\Home\Desktop\data\d_violence\bay_of_plenty.csv', index=False)

# %%
# Check total victimisations number
total_vic = df['Victimisations'].sum()
total_vic
# Out:
# 4680

# %%
# Save the geo information to draw the map
geo = data[['Victimisations' ,'Police Station', 'Rov Subdivision']]
geo = geo[geo['Rov Subdivision'] == 'Family Member']
geo.to_csv(r'\\file\Usersn$\npa95\Home\Desktop\data\d_violence\geo.csv', index=False)
